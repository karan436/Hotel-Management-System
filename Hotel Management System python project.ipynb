# %%
class Hotelmanage:
    def __init__(self,rt='',s=0,p=0,r=0,t=0,a=900,name='',address='',cindate='',coutdate='',rno=6):
        print ("\t\t\t\t\t*****WELCOME TO HOTEl TAJ*****\t\t\t\t\t")
        self.rt=rt
        self.r=r
        self.t=t
        self.p=p
        self.s=s
        self.a=a
        self.name=name
        self.address=address
        self.cindate=cindate
        self.coutdate=coutdate
        self.rno=rno
    
    def inputdata(self):
        self.name=input("\nEnter your Fullname:")
        self.address=input("\nEnter your address:")
        self.cindate=input("\nEnter your check in date:")
        self.coutdate=input("\nEnter your checkout date:")
        
        
    def roomrent(self):
        print ("We have the following rooms for you:-")
        print ("1.Standard Non Ac---->3000")
        print ("2.Standard Ac---->4000")
        print ("3.3 Bed Non Ac---->1000")
        print ("4.3 Bed Ac---->2000")

        x=int(input("Enter the number of your choice Please->"))

        n=int(input("For How Many Nights Did You Stay:"))

        if x==1:

            print ("you have choose room Standard Non Ac")

            self.s=3000*n

        elif x==2:

            print ("you have choose room Standard Ac")

            self.s=4000*n

        elif x==3:

            print ("you have choose room 3 Bed Non Ac")

            self.s=1000*n

        elif x==4:
            print ("you have choose room 3 Bed Ac")

            self.s=2000*n

        else:

            print ("please choose a room")

        print ("your choosen room rent is =",self.s,"\n")

    def foodpurchased(self):

        print("***RESTAURANT MENU***")

        print("1.Dessert-->50","2.Drinks-->120","3.Breakfast-->100","4.Lunch-->110","5.Dinner-->250","6.Exit")

        while (1):

            c=int(input("Enter the number of your choice:"))
            if c==1:
                d=int(input("Enter the quantity:"))
                self.r=self.r+50*d
            elif c==2:
                d=int(input("Enter the quantity:"))
                self.r=self.r+120*d
            elif c==3:
                d=int(input("Enter the quantity:"))
                self.r=self.r+100*d
            elif c==4:
                d=int(input("Enter the quantity:"))
                self.r=self.r+110*d
            elif c==5:
                d=int(input("Enter the quantity:"))
                self.r=self.r+250*d
            elif c==6:
                break
            else:
                print("You've Enter an Invalid Key")

        print ("Total food Cost=Rs",self.r,"\n")

    def display(self):
        print ("******HOTEL BILL******")
        print ("Customer details:")
        print ("Customer name:",self.name)
        print ("Customer address:",self.address)
        print ("Check in date:",self.cindate)
        print ("Check out date",self.coutdate)
        print ("Room no.",self.rno)
        print ("Your Room rent is:",self.s)
        print ("Your Food bill is:",self.r)

        self.rt=self.s+self.t+self.p+self.r
        
        
        print ("Your sub total Purchased is:",self.rt)
        print ("Additional Service Charges is",self.a)
        print ("Your grandtotal Purchased is:",self.rt+self.a,"\n")
        
        

def main():
    a=Hotelmanage()

    while (1):
        b=int(input("\nEnter the number of your choice:"))
        if b==1:
            print("1.Enter Customer Data")
            a.inputdata()
        if b==2:
            print("3.Calculate Room Rent")
            a.roomrent()
        if b==3:
            print("4.Calculate Food Purchased")
            a.foodpurchased()
        if b==4:
            print("5.Show total cost")
            a.display()
        if b==5:
            print("Exit")
            break
            

main()
print("\t\t\t\tThank you visit again\t\t\t\t")
# Out:
# 					*****WELCOME TO HOTEl TAJ*****
#
# Enter the number of your choice:1
# 1.Enter Customer Data
#
# Enter your Fullname:Karan Jagadale
#
# Enter your address:Navi Mumbai
#
# Enter your check in date:12/12/2022
#
# Enter your checkout date:15/12/2022
#
# Enter the number of your choice:2
# 3.Calculate Room Rent
# We have the following rooms for you:-
# 1.Standard Non Ac---->3000
# 2.Standard Ac---->4000
# 3.3 Bed Non Ac---->1000
# 4.3 Bed Ac---->2000
# Enter the number of your choice Please->2
# For How Many Nights Did You Stay:3
# you have choose room Standard Ac
# your choosen room rent is = 12000
#
#
# Enter the number of your choice:3
# 4.Calculate Food Purchased
# ***RESTAURANT MENU***
# 1.Dessert-->50 2.Drinks-->120 3.Breakfast-->100 4.Lunch-->110 5.Dinner-->250 6.Exit
# Enter the number of your choice:3
# Enter the quantity:4
# Enter the number of your choice:2
# Enter the quantity:3
# Enter the number of your choice:6
# Total food Cost=Rs 760
#
#
# ...

# %% [markdown]
# ##
